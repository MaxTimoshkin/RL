# %%
# !pip3 install box2d-py
# Out:
# Requirement already satisfied: box2d-py in /usr/local/lib/python3.7/dist-packages (2.3.8)

# %%
# !pip install gym pyvirtualdisplay > /dev/null 2>&1
# !apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1

# HIDE OUTPUT
# !apt-get update > /dev/null 2>&1
# !apt-get install cmake > /dev/null 2>&1
# !pip install --upgrade setuptools 2>&1
# !pip install ez_setup > /dev/null 2>&1
# !pip install gym[atari] > /dev/null 2>&1
# Out:
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (62.1.0)

# %%
import gym
from gym.wrappers import Monitor
import glob
import io
import base64
from IPython.display import HTML
from pyvirtualdisplay import Display
from IPython import display as ipythondisplay

display = Display(visible=0, size=(1400, 900))
display.start()

"""
Utility functions to enable video recording of gym environment 
and displaying it.
To enable video, just do "env = wrap_env(env)""
"""

def show_video():
  mp4list = glob.glob('video/*.mp4')
  if len(mp4list) > 0:
    mp4 = mp4list[0]
    video = io.open(mp4, 'r+b').read()
    encoded = base64.b64encode(video)
    ipythondisplay.display(HTML(data='''<video alt="test" autoplay 
                loop controls style="height: 400px;">
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii'))))
  else: 
    print("Could not find video")

def wrap_env(env):
  env = Monitor(env, './video', force=True)
  return env

# %%
# Класс для обучения
import tensorflow as tf
import gym
from keras import models
from keras import layers
from tensorflow.keras.optimizers import Adam
from collections import deque
import random
import numpy as np
from tensorflow import keras

tf.keras.backend.clear_session()
tf.config.optimizer.set_jit(True) # Enable XLA
tf.config.list_logical_devices()
# Out:
# [LogicalDevice(name='/device:CPU:0', device_type='CPU'),
#  LogicalDevice(name='/device:GPU:0', device_type='GPU')]

# %%
class LunarLanderTrain:
    def __init__(self, env, eps=1):
        self.env = env
        self.gamma = 0.99

        self.epsilon = eps
        self.epsilon_decay = 0.0075
        self.epsilon_min = 0.01

        self.learing_rate = 0.001
        self.replay_buffer = deque(maxlen=20000)

        self.episode_num = 400
        self.num_pick_from_buffer = 32

        self.train_network = self.create_network()
        self.target_network = self.create_network()
        self.target_network.set_weights(self.train_network.get_weights())

    def create_network(self):
        inputs = keras.Input(shape=env.observation_space.shape)
        x = layers.Dense(32, activation='relu')(inputs)
        x = layers.Dense(64, activation='relu')(x)
        outputs = layers.Dense(self.env.action_space.n, activation='linear')(x)
        model = keras.Model(inputs=inputs, outputs=outputs)
        model.compile(loss='mse', optimizer=Adam(learning_rate=self.learing_rate))
        return model

    def get_action(self, state):
        self.epsilon = max(self.epsilon_min, self.epsilon)
        if np.random.rand(1) < self.epsilon:
            action = np.random.randint(0, 4)
        else:
            action = np.argmax(self.train_network.predict(state.reshape((1,) + state.shape)))
        return action

    def train_from_buffer(self):
        if len(self.replay_buffer) < self.num_pick_from_buffer:
            return
        samples = random.sample(self.replay_buffer, self.num_pick_from_buffer)
        states, actions, rewards, newstates, dones = zip(*samples)
        states, actions, rewards, newstates, dones = np.array(states), np.array(actions), np.array(rewards), np.array(newstates), np.array(dones)
        notdones = ~dones

        targets = self.train_network.predict(states)
        Q_futures = self.target_network.predict(newstates).max(axis = 1)
        targets[(np.arange(self.num_pick_from_buffer), actions)] = rewards * dones + (rewards + Q_futures * self.gamma) * notdones
        self.train_network.fit(states, targets, epochs=1, verbose=0)


    def orginal_try(self, state, eps):
        max_reward = -99

        while True:
            action = self.get_action(state)
            new_state, reward, done, _ = env.step(action)

            if reward > max_reward:
                max_reward = reward

            self.replay_buffer.append([state, action, reward, new_state, done])
            self.train_from_buffer()

            state = new_state
            if done: break

        self.train_network.save('trainNetworkInEPS{}.h5'.format(eps))
        self.target_network.set_weights(self.train_network.get_weights())

        print("it = {}, reward = {}, max_reward = {}, eps = {}".format(eps, reward, max_reward, max(self.epsilon_min, self.epsilon)))
        self.epsilon -= self.epsilon_decay

    def start(self):
        for eps in range(self.episode_num):
            state = env.reset()
            self.orginal_try(state, eps)

# %%
#Обучение
env = gym.make('LunarLander-v2')
dqn = LunarLanderTrain(env = env)
dqn.start()
# Out:
# it = 0, reward = -100, max_reward = 0.037916706947698914, eps = 1
# it = 1, reward = -100, max_reward = 27.424044017197247, eps = 0.9925
# it = 2, reward = -100, max_reward = 12.143199333352339, eps = 0.9850000000000001
# it = 3, reward = -100, max_reward = 20.78168163820689, eps = 0.9775000000000001
# it = 4, reward = -100, max_reward = 6.663352032629548, eps = 0.9700000000000002
# it = 5, reward = -100, max_reward = 12.492645216341602, eps = 0.9625000000000002
# it = 6, reward = -100, max_reward = 17.212395846288473, eps = 0.9550000000000003
# it = 7, reward = -100, max_reward = 76.13961237246443, eps = 0.9475000000000003
# it = 8, reward = -100, max_reward = 6.2832909877379, eps = 0.9400000000000004
# it = 9, reward = -100, max_reward = 7.185304048932903, eps = 0.9325000000000004
# it = 10, reward = -100, max_reward = 12.483068464131122, eps = 0.9250000000000005
# it = 11, reward = -100, max_reward = 9.74416172720252, eps = 0.9175000000000005
# it = 12, reward = -100, max_reward = 7.283342366448182, eps = 0.9100000000000006
# it = 13, reward = -100, max_reward = 12.8859648860908, eps = 0.9025000000000006
# it = 14, reward = -100, max_reward = 5.572863004484589, eps = 0.8950000000000007
# it = 15, reward = -100, max_reward = 26.034828065376814, eps = 0.8875000000000007
# it = 16, reward = -100, max_reward = 7.931182046698042, eps = 0.8800000000000008
# it = 17, reward = -100, max_reward = 9.306683694666447, eps = 0.8725000000000008
# it = 18, reward = -100, max_reward = 72.9969588257496, eps = 0.8650000000000009
# it = 19, reward = -100, max_reward = 5.633163616387521, eps = 0.8575000000000009
# it = 20, reward = -100, max_reward = 10.810514464187463, eps = 0.850000000000001
# it = 21, reward = -100, max_reward = 0.34370792064950817, eps = 0.842500000000001
# it = 22, reward = -100, max_reward = 56.35903156520274, eps = 0.8350000000000011
# it = 23, reward = -100, max_reward = 3.5042058554737823, eps = 0.8275000000000011
# it = 24, reward = -100, max_reward = 1.1399229598243334, eps = 0.8200000000000012
# it = 25, reward = -100, max_reward = 6.087780191008904, eps = 0.8125000000000012
# it = 26, reward = -100, max_reward = 8.001492471704553, eps = 0.8050000000000013
# it = 27, reward = -100, max_reward = 6.362328572934956, eps = 0.7975000000000013
# it = 28, reward = -100, max_reward = 13.413230654316779, eps = 0.7900000000000014
# it = 29, reward = -100, max_reward = 4.431802844543995, eps = 0.7825000000000014
# it = 30, reward = -100, max_reward = 22.531649601580398, eps = 0.7750000000000015
# it = 31, reward = -100, max_reward = 7.77557807512784, eps = 0.7675000000000015
# it = 32, reward = -100, max_reward = 70.89242590296315, eps = 0.7600000000000016
# it = 33, reward = -100, max_reward = 11.449217167746582, eps = 0.7525000000000016
# it = 34, reward = -100, max_reward = 13.371421211576813, eps = 0.7450000000000017
# it = 35, reward = -100, max_reward = 86.36233972762992, eps = 0.7375000000000017
# it = 36, reward = -100, max_reward = 13.889052124679267, eps = 0.7300000000000018
# it = 37, reward = -100, max_reward = 28.029158616183366, eps = 0.7225000000000018
# it = 38, reward = -100, max_reward = 10.254800786089874, eps = 0.7150000000000019
# it = 39, reward = -100, max_reward = 13.901999033285744, eps = 0.7075000000000019
# it = 40, reward = -100, max_reward = 11.687226226918314, eps = 0.700000000000002
# it = 41, reward = -100, max_reward = 16.826379619128385, eps = 0.692500000000002
# it = 42, reward = -100, max_reward = 8.857598266095476, eps = 0.685000000000002
# it = 43, reward = -100, max_reward = 9.59843310027509, eps = 0.6775000000000021
# it = 44, reward = -100, max_reward = 5.786744057751361, eps = 0.6700000000000021
# it = 45, reward = -100, max_reward = 10.806510832181925, eps = 0.6625000000000022
# it = 46, reward = -100, max_reward = 13.7928317514456, eps = 0.6550000000000022
# it = 47, reward = -100, max_reward = 13.452134678640487, eps = 0.6475000000000023
# it = 48, reward = -100, max_reward = 11.151896782998175, eps = 0.6400000000000023
# it = 49, reward = -100, max_reward = 21.622436308901655, eps = 0.6325000000000024
# it = 50, reward = -100, max_reward = 16.42467675601868, eps = 0.6250000000000024
# it = 51, reward = -100, max_reward = 12.210293115938054, eps = 0.6175000000000025
# it = 52, reward = -100, max_reward = 7.827436976248618, eps = 0.6100000000000025
# it = 53, reward = -100, max_reward = 11.777014284283137, eps = 0.6025000000000026
# it = 54, reward = -100, max_reward = 16.09908536447939, eps = 0.5950000000000026
# it = 55, reward = -100, max_reward = 15.94841325892845, eps = 0.5875000000000027
# it = 56, reward = -100, max_reward = 10.136431929621505, eps = 0.5800000000000027
# it = 57, reward = -100, max_reward = 12.13025913261234, eps = 0.5725000000000028
# it = 58, reward = -100, max_reward = 7.08349268462547, eps = 0.5650000000000028
# it = 59, reward = -100, max_reward = 19.89769936710719, eps = 0.5575000000000029
# it = 60, reward = -100, max_reward = 7.437606482295949, eps = 0.5500000000000029
# it = 61, reward = -100, max_reward = 11.86370143862133, eps = 0.542500000000003
# it = 62, reward = -100, max_reward = 13.193700899629095, eps = 0.535000000000003
# it = 63, reward = -100, max_reward = 10.817169554334878, eps = 0.5275000000000031
# it = 64, reward = -100, max_reward = 33.10097763561494, eps = 0.5200000000000031
# it = 65, reward = -100, max_reward = 15.09083069940591, eps = 0.5125000000000032
# it = 66, reward = -100, max_reward = 46.61531701901731, eps = 0.5050000000000032
# it = 67, reward = -100, max_reward = 20.377458030583146, eps = 0.4975000000000032
# it = 68, reward = -100, max_reward = 9.184995619733513, eps = 0.4900000000000032
# it = 69, reward = -100, max_reward = 15.31752159056748, eps = 0.4825000000000032
# it = 70, reward = -100, max_reward = 25.050077037611555, eps = 0.4750000000000032
# it = 71, reward = -100, max_reward = 11.309727246023737, eps = 0.4675000000000032
# it = 72, reward = -100, max_reward = 24.391885131062452, eps = 0.4600000000000032
# it = 73, reward = -100, max_reward = 18.522074166172516, eps = 0.4525000000000032
# it = 74, reward = -100, max_reward = 13.125480276569771, eps = 0.44500000000000317
# it = 75, reward = -18.63393690830499, max_reward = 27.0211136741767, eps = 0.43750000000000316
# it = 76, reward = 1.4117715659255878, max_reward = 17.426354337431956, eps = 0.43000000000000316
# it = 77, reward = -100, max_reward = 12.217220928305963, eps = 0.42250000000000315
# it = 78, reward = -100, max_reward = 24.86315743380359, eps = 0.41500000000000314
# it = 79, reward = -100, max_reward = 9.444674137550168, eps = 0.40750000000000314
# it = 80, reward = 0.4606498145426812, max_reward = 13.219336875274664, eps = 0.40000000000000313
# it = 81, reward = -0.9134101214275248, max_reward = 22.783726423287572, eps = 0.3925000000000031
# it = 82, reward = -1.4601726840041167, max_reward = 15.519811962617847, eps = 0.3850000000000031
# it = 83, reward = 0.18544841936009676, max_reward = 19.09210741423774, eps = 0.3775000000000031
# it = 84, reward = -100, max_reward = 9.632043758300394, eps = 0.3700000000000031
# it = 85, reward = -100, max_reward = 18.9868820761705, eps = 0.3625000000000031
# it = 86, reward = -100, max_reward = 21.409897949416546, eps = 0.3550000000000031
# it = 87, reward = -100, max_reward = 8.808117865837755, eps = 0.3475000000000031
# it = 88, reward = -2.013097808183263, max_reward = 20.663076747116396, eps = 0.3400000000000031
# it = 89, reward = -3.8047438247089316, max_reward = 17.713633357176377, eps = 0.33250000000000307
# it = 90, reward = -0.5676682670411697, max_reward = 17.238744879352385, eps = 0.32500000000000306
# it = 91, reward = -2.1600096536647326, max_reward = 5.194664351708991, eps = 0.31750000000000306
# it = 92, reward = 2.5982608717622937, max_reward = 4.954977768096694, eps = 0.31000000000000305
# it = 93, reward = -1.8331957864983182, max_reward = 24.143039663111956, eps = 0.30250000000000304
# it = 94, reward = -100, max_reward = 5.742419541868554, eps = 0.29500000000000304
# it = 95, reward = -100, max_reward = 8.93995603985573, eps = 0.28750000000000303
# it = 96, reward = -100, max_reward = 4.872561887827186, eps = 0.280000000000003
# it = 97, reward = -100, max_reward = 10.161641231924621, eps = 0.272500000000003
# it = 98, reward = -0.6139924634253191, max_reward = 5.391727965712886, eps = 0.265000000000003
# it = 99, reward = 1.42957417593243, max_reward = 24.10409857239867, eps = 0.257500000000003
# it = 100, reward = -1.4308179454118204, max_reward = 21.477950331712435, eps = 0.250000000000003
# it = 101, reward = -1.9732007046042555, max_reward = 16.62154687469066, eps = 0.242500000000003
# it = 102, reward = -0.3888890721760905, max_reward = 6.135211238851352, eps = 0.23500000000000298
# it = 103, reward = 1.1784182474667066, max_reward = 19.677393196212513, eps = 0.22750000000000298
# it = 104, reward = 1.3067861716069586, max_reward = 5.159708464586328, eps = 0.22000000000000297
# it = 105, reward = 1.0522787068277253, max_reward = 4.997806938131288, eps = 0.21250000000000296
# it = 106, reward = 100, max_reward = 100, eps = 0.20500000000000296
# it = 107, reward = -0.04636569428452758, max_reward = 4.961560527458244, eps = 0.19750000000000295
# it = 108, reward = -0.02272270230037776, max_reward = 24.243222819560458, eps = 0.19000000000000294
# it = 109, reward = -0.945242172944005, max_reward = 5.06320988996917, eps = 0.18250000000000294
# it = 110, reward = 1.4199038959244248, max_reward = 5.385846535521108, eps = 0.17500000000000293
# it = 111, reward = -1.4757574228501464, max_reward = 22.81751860622252, eps = 0.16750000000000292
# it = 112, reward = -1.746972231916945, max_reward = 4.822201606007707, eps = 0.16000000000000292
# it = 113, reward = -100, max_reward = 4.946600303448389, eps = 0.1525000000000029
# it = 114, reward = -1.949146414388575, max_reward = 5.85940149218639, eps = 0.1450000000000029
# it = 115, reward = 1.5672118530695454, max_reward = 10.603074263293324, eps = 0.1375000000000029
# it = 116, reward = 0.6047069685288957, max_reward = 21.458631459726618, eps = 0.1300000000000029
# it = 117, reward = 100, max_reward = 100, eps = 0.12250000000000288
# it = 118, reward = 0.6490163408610499, max_reward = 14.621083457572919, eps = 0.11500000000000288
# it = 119, reward = 0.41070214400311045, max_reward = 22.021374458144734, eps = 0.10750000000000287
# it = 120, reward = -1.283695035964864, max_reward = 12.27977086322251, eps = 0.10000000000000286
# it = 121, reward = -2.2692112558304545, max_reward = 9.605232558971178, eps = 0.09250000000000286
# it = 122, reward = -1.7268741517576942, max_reward = 4.94294912179019, eps = 0.08500000000000285
# it = 123, reward = -0.23648619694190273, max_reward = 4.801575793879448, eps = 0.07750000000000284
# it = 124, reward = -2.501303827013402, max_reward = 5.20423952467753, eps = 0.07000000000000284
# it = 125, reward = 0.1912837190888766, max_reward = 5.409573549513209, eps = 0.06250000000000283

# %%
#Обучение
env = gym.make('LunarLander-v2')
dqn = LunarLanderTrain(env = env)
dqn.train_network.load_weights('trainNetworkInEPS125.h5')
dqn.epsilon = 0.06250000000000283
dqn.start()
# Out:
# it = 0, reward = 100, max_reward = 100, eps = 0.06250000000000283
# it = 1, reward = -100, max_reward = 3.4805655219744382, eps = 0.05500000000000283
# it = 2, reward = -100, max_reward = 5.702614364544741, eps = 0.04750000000000283
# it = 3, reward = -100, max_reward = 4.784370425433708, eps = 0.04000000000000283
# it = 4, reward = -100, max_reward = 2.537401568147119, eps = 0.03250000000000283
# it = 5, reward = -100, max_reward = 3.358698749925492, eps = 0.025000000000002832
# it = 6, reward = -100, max_reward = 5.232558578803531, eps = 0.017500000000002833
# it = 7, reward = -100, max_reward = 3.7754941483805853, eps = 0.010000000000002833
# it = 8, reward = -0.2807337148370436, max_reward = 4.591073961497, eps = 0.01
# it = 9, reward = -100, max_reward = 3.350887870698301, eps = 0.01
# it = 10, reward = -100, max_reward = 2.472435847151144, eps = 0.01
# it = 11, reward = -100, max_reward = 2.7898416531617274, eps = 0.01
# it = 12, reward = -100, max_reward = 1.7049621453568318, eps = 0.01
# it = 13, reward = -100, max_reward = 7.4443728305701145, eps = 0.01
# it = 14, reward = -100, max_reward = 17.39141285296682, eps = 0.01
# it = 15, reward = -100, max_reward = 4.717484014449735, eps = 0.01
# it = 16, reward = -100, max_reward = 4.693738335254904, eps = 0.01
# it = 17, reward = 16.420020381170417, max_reward = 16.420020381170417, eps = 0.01
# it = 18, reward = -100, max_reward = 2.463484236982606, eps = 0.01
# it = 19, reward = -0.5609864514937215, max_reward = 4.721291677402246, eps = 0.01
# it = 20, reward = 1.1013314884024055, max_reward = 5.417204591288436, eps = 0.01
# it = 21, reward = 1.1842668351506915, max_reward = 5.611706764328955, eps = 0.01
# it = 22, reward = -0.4115011087324376, max_reward = 4.692128605539762, eps = 0.01
# it = 23, reward = 0.4833161480486979, max_reward = 3.356291687754248, eps = 0.01
# it = 24, reward = -100, max_reward = 4.997971081935714, eps = 0.01
# it = 25, reward = 1.8511773039402328, max_reward = 4.297738645984691, eps = 0.01
# it = 26, reward = 3.7279393604978397, max_reward = 3.7279393604978397, eps = 0.01
# it = 27, reward = -100, max_reward = 14.307506001652467, eps = 0.01
# it = 28, reward = 0.8966026758827297, max_reward = 3.8230503220980667, eps = 0.01
# it = 29, reward = 100, max_reward = 100, eps = 0.01
# it = 30, reward = -2.065335534003651, max_reward = 4.011607894787216, eps = 0.01
# it = 31, reward = 0.22178577320387377, max_reward = 3.258037614135458, eps = 0.01
# it = 32, reward = 100, max_reward = 100, eps = 0.01
# it = 33, reward = -100, max_reward = 19.445597100609543, eps = 0.01
# it = 34, reward = -2.157347378333543, max_reward = 4.694647065692675, eps = 0.01
# it = 35, reward = 100, max_reward = 100, eps = 0.01
# it = 36, reward = 0.62500176115837, max_reward = 3.458536416261535, eps = 0.01
# it = 37, reward = -100, max_reward = 24.74178000488119, eps = 0.01
# it = 38, reward = 100, max_reward = 100, eps = 0.01
# it = 39, reward = 100, max_reward = 100, eps = 0.01
# it = 40, reward = 100, max_reward = 100, eps = 0.01
# it = 41, reward = -100, max_reward = 18.939537070567436, eps = 0.01
# it = 42, reward = 100, max_reward = 100, eps = 0.01
# it = 43, reward = 100, max_reward = 100, eps = 0.01
# it = 44, reward = 100, max_reward = 100, eps = 0.01
# it = 45, reward = 100, max_reward = 100, eps = 0.01
# it = 46, reward = 100, max_reward = 100, eps = 0.01
# it = 47, reward = 0.059675529108206504, max_reward = 15.70157102699211, eps = 0.01
# it = 48, reward = -3.084820834577161, max_reward = 10.707841224389039, eps = 0.01
# it = 49, reward = 100, max_reward = 100, eps = 0.01
# it = 50, reward = 100, max_reward = 100, eps = 0.01
# it = 51, reward = 100, max_reward = 100, eps = 0.01
# it = 52, reward = 100, max_reward = 100, eps = 0.01
# it = 53, reward = -100, max_reward = 10.930952107314493, eps = 0.01
# it = 54, reward = 100, max_reward = 100, eps = 0.01
# it = 55, reward = 100, max_reward = 100, eps = 0.01
# it = 56, reward = 100, max_reward = 100, eps = 0.01
# it = 57, reward = 100, max_reward = 100, eps = 0.01
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-5486ed21d0a4> in <module>()
#       4 dqn.train_network.load_weights('trainNetworkInEPS125.h5')
#       5 dqn.epsilon = 0.06250000000000283
# ----> 6 dqn.start()
#
# <ipython-input-5-c84bcaf53018> in start(self)
#      74         for eps in range(self.episode_num):
#      75             state = env.reset()
# ---> 76             self.orginal_try(state, eps)
#
# <ipython-input-5-c84bcaf53018> in orginal_try(self, state, eps)
#      60
#      61             self.replay_buffer.append([state, action, reward, new_state, done])
# ---> 62             self.train_from_buffer()
#      63
#      64             state = new_state
#
# <ipython-input-5-c84bcaf53018> in train_from_buffer(self)
#      43         notdones = ~dones
#      44
# ---> 45         targets = self.train_network.predict(states)
#      46         Q_futures = self.target_network.predict(newstates).max(axis = 1)
#      47         targets[(np.arange(self.num_pick_from_buffer), actions)] = rewards * dones + (rewards + Q_futures * self.gamma) * notdones
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1976       callbacks.on_predict_begin()
#    1977       batch_outputs = None
# -> 1978       for _, iterator in data_handler.enumerate_epochs():  # Single epoch.
#    1979         with data_handler.catch_stop_iteration():
#    1980           for step in data_handler.steps():
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/data_adapter.py in enumerate_epochs(self)
#    1189     """Yields `(epoch, tf.data.Iterator)`."""
#    1190     with self._truncate_execution_to_epoch():
# -> 1191       data_iterator = iter(self._dataset)
#    1192       for epoch in range(self._initial_epoch, self._epochs):
#    1193         if self._insufficient_data:  # Set by `catch_stop_iteration`.
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/dataset_ops.py in __iter__(self)
#     484     if context.executing_eagerly() or ops.inside_function():
#     485       with ops.colocate_with(self._variant_tensor):
# --> 486         return iterator_ops.OwnedIterator(self)
#     487     else:
#     488       raise RuntimeError("`tf.data.Dataset` only supports Python-style "
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/iterator_ops.py in __init__(self, dataset, components, element_spec)
#     753             "When `dataset` is provided, `element_spec` and `components` must "
#     754             "not be specified.")
# --> 755       self._create_iterator(dataset)
#     756
#     757     self._get_next_call_count = 0
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/iterator_ops.py in _create_iterator(self, dataset)
#     785                 output_types=self._flat_output_types,
#     786                 output_shapes=self._flat_output_shapes))
# --> 787         gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#     788         # Delete the resource when this object is deleted
#     789         self._resource_deleter = IteratorResourceDeleter(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/gen_dataset_ops.py in make_iterator(dataset, iterator, name)
#    3314     try:
#    3315       _result = pywrap_tfe.TFE_Py_FastPathExecute(
# -> 3316         _ctx, "MakeIterator", name, dataset, iterator)
#    3317       return _result
#    3318     except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
#Проверка
env = wrap_env(gym.make('LunarLander-v2'))
dqn = LunarLanderTrain(env = env, eps=0)
dqn.train_network.load_weights('trainNetworkInEPS51.h5') # ТОП = {38, 39, 42, 43, 45, 46, 47, 49, (51), 53, 54, 55, 56}

state = env.reset()

while True:
    env.render()
    action = dqn.get_action(state) 
    state, reward, done, info = env.step(action)  
    if done: break;
            
env.close()
show_video()
print(reward)
# Out:
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>
# 100

# %%
state
# первые 2 - это положение по оси x и оси y (высота), 
# другие 2 - это условия скорости по осям x, y, 
# угол посадочного модуля и угловая скорость, 
# левая и правая левые точки контакта (bool )
# Out:
# array([ 0.3058899 ,  0.02807165,  0.01110496, -0.77348167,  0.32755476,
#         4.867282  ,  1.        ,  1.        ], dtype=float32)

# %%
env.action_space
# Out:
# Discrete(4)
